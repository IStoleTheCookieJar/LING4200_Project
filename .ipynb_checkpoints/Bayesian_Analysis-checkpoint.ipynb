# %%
import nltk
import random
import numpy as np
from datetime import datetime as dt
import os
import glob
from nltk.text import Text
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('punkt_tab')
print(os.listdir())
os.chdir("/home/jovyan/LING4200_Project")
print(os.getcwd())
cwd = os.getcwd()
print(cwd)
# Out:
# ['logo_modernism', 'Bayesian_Analysis.ipynb', '.git', 'code_document_classify_use.py', 'beholdapalehorsebymiltonwilliamcooper1991_202003', 'code_document_classify_fd.py', '10s', '90s', '.ipynb_checkpoints', 'File_Downloading.ipynb']
# /home/jovyan/LING4200_Project
# /home/jovyan/LING4200_Project
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /home/jovyan/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt_tab to /home/jovyan/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %% [markdown]
# ### Example Process

# %% [markdown]
# ##### Setup

# %%
# from nltk.corpus import movie_reviews
# documents = [(list(movie_reviews.words(fileid)),category) for category in movie_reviews.categories()\
#             for fileid in movie_reviews.fileids(category)]
# random.shuffle(documents) # Setting up the documents list that contains: All documents from the movie_reviews
# List will contain [document1, document2, document3...] where document1 contains [review text, pos or neg review]

# %%
# all_words = nltk.FreqDist(w.lower() for w in movie_reviews.words()) # all words in order similar to document list?

# %% [markdown]
# ##### Feature Extractor

# %%
# word_features = list(all_words)[:2000] # 2000 most common words in all movie_review corpus

# def document_features(document): # define feature extractor
#     document_words = set(document) # builds an iterable from document (likely just a list/set of words from the movie_review)
#                                     # sets are very quick to check (word in document_words) compared to checking lists
#     features = {} # dictionary
#     for word in word_features: # Iterate through all 2000 most common words in the corpus
#         features['contains({})'.format(word)] = (word in document_words) # create dictionary index with value TRUE or FALSE
#                                                                         # Depending on if word is in document_words
#     return features

# %%
# print(list(document_features(movie_reviews.words('pos/cv957_8737.txt')).items())[:10]) # test

# %% [markdown]
# ##### Training

# %%
# featuresets = [(document_features(d),c) for (d,c) in documents] # contains 2000 word existences in movie review and whether it was
#                                                     # negative or positive
# # structured as [document1, document2, document3, ...] where document1 is structured as [contains words, neg or pos]

# %%
# featuresets[0]

# %%
# train_set,test_set = featuresets[:int(len(featuresets)*0.8)],featuresets[int(len(featuresets)*0.8):] 
# # 80 20 split for test and train

# %%
# classifier = nltk.NaiveBayesClassifier.train(train_set) # train using built in

# %%
# print(nltk.classify.accuracy(classifier, test_set)) # see the accuracy of the program

# %%
# classifier.show_most_informative_features(5) # 5 most influential features

# %% [markdown]
# ### Real Data

# %%
# %%time
texts = []
files_90s = glob.glob(cwd+"/90s/*.txt")
# print(files_90s)
for i,file in enumerate(files_90s):
    try:
        file_sub = open(file, "r")
        text = file_sub.read()
        file_sub.close()
        
    except UnicodeDecodeError:
        continue
    tokens = nltk.word_tokenize(text)
    tokens = tokens[int(len(tokens)*.1):int(len(tokens)*.9)]
    j = 0
    while j < len(tokens):
        if(not(tokens[j].lower().isalpha())):
            del(tokens[j])
            j-=1
        j+=1
    texts.append((tokens,"90s"))
files_10s = glob.glob(cwd+"/10s/*.txt")
for i,file in enumerate(files_10s):
    try:
        file_sub = open(file, "r")
        text = file_sub.read()
        file_sub.close()
    except UnicodeDecodeError:
        continue
    tokens = nltk.word_tokenize(text)
    tokens = tokens[int(len(tokens)*.1):int(len(tokens)*.9)]
    j = 0
    while j < len(tokens):
        if(not(tokens[j].lower().isalpha())):
            del(tokens[j])
            j-=1
        j+=1
    texts.append((tokens,"10s"))
    
    
    # if(i > 3):
    #     break
all_words = [x for xs in texts for x in xs[0]]
all_words = list(nltk.FreqDist(all_words))
# Out:
# CPU times: user 2min 27s, sys: 4.44 s, total: 2min 31s
# Wall time: 2min 31s

# %%
print("\n=== Concordance Analysis with POS Tagging ===")

# Create Text objects for each decade
text_1990s_tokens = [word for tokens, decade in texts if decade == "90s" for word in tokens]
text_2010s_tokens = [word for tokens, decade in texts if decade == "10s" for word in tokens]

# POS tagging
pos_1990s = nltk.pos_tag(text_1990s_tokens)
pos_2010s = nltk.pos_tag(text_2010s_tokens)

# Recreate Text objects with original tokens
text_1990s = Text(text_1990s_tokens)
text_2010s = Text(text_2010s_tokens)

# List of words for concordance analysis
word_list = ["hereof", "covenants", "undivided", "separator", "Notwithstanding", "Pooling", "therefrom", "Royalties", 
             "proportionately", "executors", "devisees", "thereunder", "Montana"]

def display_concordances_with_pos(word_list, text_1990s, text_2010s, pos_1990s, pos_2010s, width=80, lines=10):
    for word in word_list:
        print(f"\n=== Concordance and POS for '{word}' ===")
        
        # POS in 1990s text
        print("\n--- In 1990s Text ---")
        try:
            text_1990s.concordance(word, width=width, lines=lines)
            tags_1990s = [pos for token, pos in pos_1990s if token.lower() == word.lower()]
            print(f"POS Tags in 1990s: {tags_1990s}")
        except ValueError:
            print(f"'{word}' not found in 1990s text.")
        
        # POS in 2010s text
        print("\n--- In 2010s Text ---")
        try:
            text_2010s.concordance(word, width=width, lines=lines)
            tags_2010s = [pos for token, pos in pos_2010s if token.lower() == word.lower()]
            print(f"POS Tags in 2010s: {tags_2010s}")
        except ValueError:
            print(f"'{word}' not found in 2010s text.")

# Display concordances and POS tags for each word
display_concordances_with_pos(word_list, text_1990s, text_2010s, pos_1990s, pos_2010s)
# Out:
# === Concordance Analysis with POS Tagging ===
#
# === Concordance and POS for 'hereof' ===
#
# --- In 1990s Text ---
# Displaying 1 of 1 matches:
# event later than days after the date hereof c Exhibits Agreement and Plan of Reo
# POS Tags in 1990s: ['NN']
#
# --- In 2010s Text ---

# %%
print(len(all_words))
# Out:
# 215552

# %%
word_features = list(all_words)[:2000]

def text_features(text): # define feature extractor
    document_words = set(text) # builds an iterable from document (likely just a list/set of words from the movie_review)
                                    # sets are very quick to check (word in document_words) compared to checking lists
    features = {} # dictionary
    for word in word_features: # Iterate through all 2000 most common words in the corpus
        features['contains({})'.format(word)] = (word in document_words) # create dictionary index with value TRUE or FALSE
                                                                        # Depending on if word is in document_words
    return features

# %%
print(list(text_features(texts[0][0]).items())[:10]) # test
# Out:
# [('contains(the)', True), ('contains(of)', True), ('contains(and)', True), ('contains(to)', True), ('contains(or)', True), ('contains(in)', True), ('contains(a)', True), ('contains(for)', True), ('contains(Lessee)', False), ('contains(is)', True)]

# %% [markdown]
# ### Training

# %%
featuresets = [(text_features(t),c) for (t,c) in texts]

# %% [raw]
# featuresets[0]

# %%
train_set,test_set = featuresets[:int(len(featuresets)*0.8)],featuresets[int(len(featuresets)*0.8):] 
# 80 20 split for test and train

# %%
classifier = nltk.NaiveBayesClassifier.train(train_set) # train using built in

# %%
print(nltk.classify.accuracy(classifier, test_set)) # see the accuracy of the program
# Out:
# 0.793233082706767

# %%
classifier.show_most_informative_features(-1) # 5 most influential features
# Out:
# Most Informative Features
#         contains(hereof) = True              10s : 90s    =    136.9 : 1.0
#      contains(covenants) = True              10s : 90s    =    126.3 : 1.0
#      contains(undivided) = True              10s : 90s    =    126.1 : 1.0
#      contains(separator) = True              10s : 90s    =    120.0 : 1.0
# contains(Notwithstanding) = True              10s : 90s    =    119.3 : 1.0
#        contains(Pooling) = True              10s : 90s    =    116.3 : 1.0
#      contains(therefrom) = True              10s : 90s    =    113.8 : 1.0
#      contains(Royalties) = True              10s : 90s    =    109.1 : 1.0
# contains(proportionately) = True              10s : 90s    =    106.7 : 1.0
#      contains(executors) = True              10s : 90s    =    102.6 : 1.0
#       contains(devisees) = True              10s : 90s    =    101.0 : 1.0
#     contains(thereunder) = True              10s : 90s    =    101.0 : 1.0
#      contains(reworking) = True              10s : 90s    =     80.9 : 1.0
#      contains(cessation) = True              10s : 90s    =     80.5 : 1.0
#            contains(FAX) = True              90s : 10s    =     79.4 : 1.0
#      contains(commences) = True              10s : 90s    =     72.8 : 1.0
#     contains(subsurface) = True              10s : 90s    =     72.6 : 1.0
#        contains(thereon) = True              10s : 90s    =     71.9 : 1.0
#      contains(foregoing) = True              10s : 90s    =     71.4 : 1.0
#   contains(hydrocarbons) = True              10s : 90s    =     69.4 : 1.0
#        contains(Montana) = True              90s : 10s    =     68.6 : 1.0
#          contains(deems) = True              10s : 90s    =     64.6 : 1.0
#    contains(contraction) = True              10s : 90s    =     63.3 : 1.0
#   contains(insurrection) = True              10s : 90s    =     62.8 : 1.0
#          contains(skill) = True              90s : 10s    =     62.0 : 1.0
#        contains(Ontario) = True              90s : 10s    =     59.9 : 1.0
#         contains(lessor) = True              10s : 90s    =     59.1 : 1.0
#      contains(hereunder) = True              10s : 90s    =     58.6 : 1.0
#             contains(CM) = True              90s : 10s    =     55.5 : 1.0
#         contains(excise) = True              10s : 90s    =     51.3 : 1.0
#       contains(covenant) = True              10s : 90s    =     51.1 : 1.0
#      contains(easements) = True              10s : 90s    =     51.1 : 1.0
#         contains(Branch) = True              90s : 10s    =     47.7 : 1.0
#     contains(successors) = True              10s : 90s    =     47.0 : 1.0
#            contains(Bay) = True              90s : 10s    =     46.2 : 1.0
#         contains(pooled) = True              10s : 90s    =     45.9 : 1.0
#       contains(sabotage) = True              10s : 90s    =     45.3 : 1.0
#       contains(easement) = True              10s : 90s    =     45.3 : 1.0
#       contains(Canadian) = True              90s : 10s    =     45.2 : 1.0
#      contains(rebellion) = True              10s : 90s    =     45.0 : 1.0
#           contains(Call) = True              90s : 10s    =     44.3 : 1.0
#        contains(Florida) = True              90s : 10s    =     43.4 : 1.0
#           contains(farm) = True              90s : 10s    =     43.2 : 1.0
#      contains(hereafter) = True              10s : 90s    =     41.3 : 1.0
#         contains(breach) = True              10s : 90s    =     41.0 : 1.0
#           contains(Mike) = True              90s : 10s    =     41.0 : 1.0
#        contains(tenders) = True              10s : 90s    =     40.6 : 1.0
# contains(notwithstanding) = True              10s : 90s    =     40.4 : 1.0
#       contains(plumbing) = True              90s : 10s    =     40.3 : 1.0
#     contains(provincial) = True              90s : 10s    =     40.3 : 1.0
#           contains(Room) = True              90s : 10s    =     39.5 : 1.0
#           contains(race) = True              90s : 10s    =     39.5 : 1.0
#     contains(Washington) = True              90s : 10s    =     39.4 : 1.0
#    contains(hereinafter) = True              10s : 90s    =     39.0 : 1.0
#          contains(SHALL) = True              10s : 90s    =     38.9 : 1.0
#         contains(Sunday) = True              90s : 10s    =     38.7 : 1.0
#    contains(Individuals) = True              90s : 10s    =     38.5 : 1.0
#       contains(Ministry) = True              90s : 10s    =     38.5 : 1.0
#     contains(subrogated) = True              10s : 90s    =     38.1 : 1.0
#      contains(licensing) = True              90s : 10s    =     38.1 : 1.0
#        contains(Majeure) = True              10s : 90s    =     38.1 : 1.0
#       contains(fixtures) = True              10s : 90s    =     37.9 : 1.0
#    contains(geophysical) = True              10s : 90s    =     37.4 : 1.0
#        contains(royalty) = True              10s : 90s    =     37.2 : 1.0
#          contains(Files) = True              90s : 10s    =     35.9 : 1.0
#        contains(Pacific) = True              90s : 10s    =     35.9 : 1.0
#        contains(valorem) = True              10s : 90s    =     35.5 : 1.0
#       contains(tendered) = True              10s : 90s    =     35.4 : 1.0
#        contains(species) = True              90s : 10s    =     35.2 : 1.0
#        contains(Tarrant) = True              10s : 90s    =     35.1 : 1.0
#             contains(GA) = True              90s : 10s    =     34.6 : 1.0
#    contains(Mississippi) = True              90s : 10s    =     34.6 : 1.0
#      contains(enlarging) = True              10s : 90s    =     33.4 : 1.0
#          contains(liens) = True              10s : 90s    =     33.4 : 1.0
#       contains(Carolina) = True              90s : 10s    =     33.1 : 1.0
#     contains(prosecuted) = True              10s : 90s    =     32.6 : 1.0
#         contains(Mexico) = True              90s : 10s    =     32.3 : 1.0
#          contains(GROUP) = True              90s : 10s    =     31.3 : 1.0
#         contains(POOLED) = True              10s : 90s    =     31.1 : 1.0
#        contains(pooling) = True              10s : 90s    =     31.1 : 1.0
#         contains(STATUS) = True              90s : 10s    =     30.7 : 1.0
#   contains(ratification) = True              10s : 90s    =     30.1 : 1.0
#            contains(son) = True              90s : 10s    =     29.9 : 1.0
#     contains(depository) = True              10s : 90s    =     29.5 : 1.0
#            contains(San) = True              90s : 10s    =     29.4 : 1.0
#     contains(indigenous) = True              90s : 10s    =     29.4 : 1.0
#    contains(Agriculture) = True              90s : 10s    =     29.4 : 1.0
#          contains(Steve) = True              90s : 10s    =     29.4 : 1.0
#          contains(Plant) = True              90s : 10s    =     28.8 : 1.0
#    contains(exploratory) = True              10s : 90s    =     28.8 : 1.0
# contains(administration) = True              90s : 10s    =     28.5 : 1.0
#         contains(herein) = True              10s : 90s    =     28.4 : 1.0
#      contains(expressly) = True              10s : 90s    =     28.4 : 1.0
#         contains(Notary) = True              10s : 90s    =     28.3 : 1.0
#       contains(Director) = True              90s : 10s    =     27.8 : 1.0
#       contains(drilling) = True              10s : 90s    =     27.4 : 1.0
#        contains(therein) = True              10s : 90s    =     27.3 : 1.0
#       contains(Michigan) = True              90s : 10s    =     27.2 : 1.0
#         contains(member) = True              90s : 10s    =     27.1 : 1.0
#        contains(variety) = True              90s : 10s    =     27.0 : 1.0
#           contains(cent) = True              90s : 10s    =     26.9 : 1.0
# contains(qualifications) = True              90s : 10s    =     26.8 : 1.0
#        contains(Storage) = True              90s : 10s    =     26.6 : 1.0
#        contains(Persons) = True              90s : 10s    =     26.5 : 1.0
#          contains(heirs) = True              10s : 90s    =     26.5 : 1.0
#  contains(establishment) = True              90s : 10s    =     26.4 : 1.0
#          contains(weeks) = True              90s : 10s    =     26.0 : 1.0
#            contains(She) = True              90s : 10s    =     25.9 : 1.0
#            contains(YOU) = True              90s : 10s    =     25.8 : 1.0
#           contains(Miss) = True              90s : 10s    =     25.7 : 1.0
#      contains(purchaser) = True              10s : 90s    =     25.6 : 1.0
#          contains(Brown) = True              90s : 10s    =     25.5 : 1.0
#           contains(lien) = True              10s : 90s    =     25.2 : 1.0
#         contains(casing) = True              10s : 90s    =     25.1 : 1.0
#   contains(acknowledges) = True              10s : 90s    =     25.1 : 1.0
#        contains(OUTSIDE) = True              90s : 10s    =     25.0 : 1.0
#        contains(assigns) = True              10s : 90s    =     25.0 : 1.0
#          contains(Board) = True              90s : 10s    =     24.9 : 1.0
#        contains(gravity) = True              10s : 90s    =     24.9 : 1.0
#         contains(liable) = True              10s : 90s    =     24.8 : 1.0
#           contains(Phil) = True              90s : 10s    =     24.7 : 1.0
#         contains(census) = True              90s : 10s    =     24.7 : 1.0
#    contains(variability) = True              90s : 10s    =     24.7 : 1.0
#         contains(really) = True              90s : 10s    =     24.6 : 1.0
#       contains(computer) = True              90s : 10s    =     24.6 : 1.0
#      contains(Paragraph) = True              10s : 90s    =     24.4 : 1.0
#         contains(George) = True              90s : 10s    =     24.0 : 1.0
#           contains(York) = True              90s : 10s    =     23.8 : 1.0
#         contains(Policy) = True              90s : 10s    =     23.4 : 1.0
#       contains(decedent) = True              10s : 90s    =     23.3 : 1.0
#           contains(felt) = True              90s : 10s    =     23.3 : 1.0
#      contains(severance) = True              10s : 90s    =     23.2 : 1.0
#      contains(technical) = True              90s : 10s    =     23.2 : 1.0
#        contains(spacing) = True              10s : 90s    =     22.9 : 1.0
#        contains(Alabama) = True              90s : 10s    =     22.9 : 1.0
#       contains(probably) = True              90s : 10s    =     22.9 : 1.0
#        contains(Arizona) = True              90s : 10s    =     22.9 : 1.0
#        contains(Georgia) = True              90s : 10s    =     22.9 : 1.0
#          contains(ORDER) = True              90s : 10s    =     22.9 : 1.0
#          contains(TABLE) = True              90s : 10s    =     22.9 : 1.0
#     contains(WASHINGTON) = True              90s : 10s    =     22.9 : 1.0
#             contains(pt) = True              90s : 10s    =     22.9 : 1.0
#         contains(drills) = True              10s : 90s    =     22.6 : 1.0
#  contains(organizations) = True              90s : 10s    =     22.5 : 1.0
#        contains(Library) = True              90s : 10s    =     22.4 : 1.0
#           contains(ment) = True              90s : 10s    =     22.4 : 1.0
#         contains(Church) = True              90s : 10s    =     22.4 : 1.0
#       contains(Security) = True              90s : 10s    =     22.3 : 1.0
#          contains(Carol) = True              90s : 10s    =     22.1 : 1.0
#       contains(Although) = True              90s : 10s    =     22.0 : 1.0
#             contains(CA) = True              90s : 10s    =     22.0 : 1.0
#          contains(Class) = True              90s : 10s    =     22.0 : 1.0
#     contains(households) = True              90s : 10s    =     21.9 : 1.0
#        contains(College) = True              90s : 10s    =     21.8 : 1.0
#          contains(leave) = True              90s : 10s    =     21.8 : 1.0
#      contains(terminate) = True              10s : 90s    =     21.8 : 1.0
#            contains(Con) = True              90s : 10s    =     21.5 : 1.0
#             contains(DE) = True              90s : 10s    =     21.5 : 1.0
#  contains(proportionate) = True              10s : 90s    =     21.5 : 1.0
#        contains(clients) = True              90s : 10s    =     21.4 : 1.0
#       contains(occupied) = True              90s : 10s    =     21.4 : 1.0
#          contains(Bruce) = True              90s : 10s    =     21.3 : 1.0
#           contains(YEAR) = True              90s : 10s    =     21.3 : 1.0
#           contains(rent) = True              90s : 10s    =     21.3 : 1.0
#     contains(expiration) = True              10s : 90s    =     21.3 : 1.0
#        contains(college) = True              90s : 10s    =     21.3 : 1.0
#         contains(barrel) = True              10s : 90s    =     21.3 : 1.0
#      contains(pipelines) = True              10s : 90s    =     21.2 : 1.0
#           contains(riot) = True              10s : 90s    =     21.1 : 1.0
#           contains(Club) = True              90s : 10s    =     21.1 : 1.0
#         contains(Forest) = True              90s : 10s    =     21.1 : 1.0
#     contains(assessment) = True              90s : 10s    =     21.1 : 1.0
#         contains(depths) = True              10s : 90s    =     21.0 : 1.0
# contains(correspondence) = True              90s : 10s    =     21.0 : 1.0
#       contains(situated) = True              10s : 90s    =     21.0 : 1.0
#       contains(American) = True              90s : 10s    =     20.8 : 1.0
#       contains(subjects) = True              90s : 10s    =     20.7 : 1.0
#        contains(Because) = True              90s : 10s    =     20.6 : 1.0
#       contains(warrants) = True              10s : 90s    =     20.5 : 1.0
#          contains(tests) = True              90s : 10s    =     20.4 : 1.0
#          contains(tions) = True              90s : 10s    =     20.2 : 1.0
#           contains(says) = True              90s : 10s    =     20.0 : 1.0
#   contains(commencement) = True              10s : 90s    =     19.9 : 1.0
#             contains(CD) = True              90s : 10s    =     19.8 : 1.0
#           contains(duly) = True              10s : 90s    =     19.8 : 1.0
#         contains(played) = True              90s : 10s    =     19.8 : 1.0
#         contains(Center) = True              90s : 10s    =     19.7 : 1.0
#          contains(wells) = True              10s : 90s    =     19.5 : 1.0
#      contains(royalties) = True              10s : 90s    =     19.5 : 1.0
#         contains(status) = True              90s : 10s    =     19.5 : 1.0
#            contains(she) = True              90s : 10s    =     19.5 : 1.0
#        contains(Central) = True              90s : 10s    =     19.5 : 1.0
#         contains(Canada) = True              90s : 10s    =     19.4 : 1.0
#          contains(Human) = True              90s : 10s    =     19.4 : 1.0
#       contains(families) = True              90s : 10s    =     19.4 : 1.0
#           contains(Next) = True              90s : 10s    =     19.4 : 1.0
#       contains(Virginia) = True              90s : 10s    =     19.4 : 1.0
#         contains(formal) = True              90s : 10s    =     19.4 : 1.0
#        contains(Jackson) = True              90s : 10s    =     19.3 : 1.0
#             contains(cm) = True              90s : 10s    =     19.3 : 1.0
#        contains(meeting) = True              90s : 10s    =     19.3 : 1.0
#      contains(recurring) = True              10s : 90s    =     19.2 : 1.0
#        contains(special) = True              90s : 10s    =     19.0 : 1.0
#   contains(applications) = True              90s : 10s    =     18.9 : 1.0
#     contains(exercising) = True              10s : 90s    =     18.8 : 1.0
#         contains(Office) = True              90s : 10s    =     18.8 : 1.0
#      contains(personnel) = True              90s : 10s    =     18.7 : 1.0
#            contains(don) = True              90s : 10s    =     18.6 : 1.0
#           contains(Food) = True              90s : 10s    =     18.6 : 1.0
#        contains(prudent) = True              10s : 90s    =     18.5 : 1.0
#         contains(Indian) = True              90s : 10s    =     18.5 : 1.0
#            contains(PAC) = True              90s : 10s    =     18.5 : 1.0
#         contains(Titles) = True              90s : 10s    =     18.5 : 1.0
#           contains(food) = True              90s : 10s    =     18.5 : 1.0
#      contains(questions) = True              90s : 10s    =     18.5 : 1.0
#            contains(led) = True              90s : 10s    =     18.4 : 1.0
#       contains(Arkansas) = True              90s : 10s    =     18.2 : 1.0
#          contains(LEASE) = True              10s : 90s    =     18.1 : 1.0
#      contains(Francisco) = True              90s : 10s    =     17.8 : 1.0
#             contains(OO) = True              90s : 10s    =     17.8 : 1.0
#        contains(acreage) = True              10s : 90s    =     17.8 : 1.0
#             contains(PR) = True              90s : 10s    =     17.8 : 1.0
#     contains(purchasers) = True              10s : 90s    =     17.6 : 1.0
#        contains(binding) = True              10s : 90s    =     17.6 : 1.0
#      contains(Standards) = True              90s : 10s    =     17.5 : 1.0
#          contains(Since) = True              90s : 10s    =     17.5 : 1.0
#       contains(graduate) = True              90s : 10s    =     17.5 : 1.0
#      contains(relations) = True              90s : 10s    =     17.5 : 1.0
#        contains(classes) = True              90s : 10s    =     17.5 : 1.0
#        contains(English) = True              90s : 10s    =     17.4 : 1.0
#      contains(affiliate) = True              10s : 90s    =     17.3 : 1.0
#         contains(ceases) = True              10s : 90s    =     17.3 : 1.0
#         contains(Leased) = True              10s : 90s    =     17.2 : 1.0
#    contains(populations) = True              90s : 10s    =     17.2 : 1.0
#        contains(Michael) = True              90s : 10s    =     17.2 : 1.0
#       contains(regional) = True              90s : 10s    =     17.2 : 1.0
#        contains(drilled) = True              10s : 90s    =     17.1 : 1.0
#         contains(Manual) = True              90s : 10s    =     17.1 : 1.0
#           contains(Tech) = True              90s : 10s    =     17.1 : 1.0
#      contains(Tennessee) = True              90s : 10s    =     17.1 : 1.0
#             contains(co) = True              90s : 10s    =     17.0 : 1.0
#          contains(women) = True              90s : 10s    =     16.9 : 1.0
#     contains(population) = True              90s : 10s    =     16.9 : 1.0
#    contains(definitions) = True              90s : 10s    =     16.9 : 1.0
#         contains(Please) = True              90s : 10s    =     16.8 : 1.0
#          contains(Smith) = True              90s : 10s    =     16.8 : 1.0
#           contains(Tony) = True              90s : 10s    =     16.8 : 1.0
#         contains(player) = True              90s : 10s    =     16.8 : 1.0
#        contains(exhaust) = True              10s : 90s    =     16.8 : 1.0
#       contains(sampling) = True              90s : 10s    =     16.8 : 1.0
#         contains(revise) = True              10s : 90s    =     16.7 : 1.0
#        contains(housing) = True              90s : 10s    =     16.7 : 1.0
#           contains(tion) = True              90s : 10s    =     16.5 : 1.0
#     contains(formations) = True              10s : 90s    =     16.4 : 1.0
#         contains(CENSUS) = True              90s : 10s    =     16.3 : 1.0
#             contains(St) = True              90s : 10s    =     16.3 : 1.0
#             contains(TD) = True              90s : 10s    =     16.3 : 1.0
#           contains(code) = True              90s : 10s    =     16.3 : 1.0
#           contains(meat) = True              90s : 10s    =     16.3 : 1.0
#         contains(school) = True              90s : 10s    =     16.3 : 1.0
#             contains(ET) = True              90s : 10s    =     16.3 : 1.0
#  contains(Professionals) = True              90s : 10s    =     16.3 : 1.0
#        contains(looking) = True              90s : 10s    =     16.3 : 1.0
#           contains(room) = True              90s : 10s    =     16.3 : 1.0
#       contains(relieved) = True              10s : 90s    =     16.2 : 1.0
#          contains(White) = True              90s : 10s    =     16.1 : 1.0
#         contains(ninety) = True              10s : 90s    =     16.0 : 1.0
#             contains(ve) = True              90s : 10s    =     16.0 : 1.0
#         contains(senior) = True              90s : 10s    =     16.0 : 1.0
#    contains(declaration) = True              10s : 90s    =     15.9 : 1.0
#         contains(hereby) = True              10s : 90s    =     15.9 : 1.0
# contains(Administration) = True              90s : 10s    =     15.8 : 1.0
#           contains(Work) = True              90s : 10s    =     15.8 : 1.0
#         contains(season) = True              90s : 10s    =     15.8 : 1.0
#           contains(seen) = True              90s : 10s    =     15.8 : 1.0
#        contains(Systems) = True              90s : 10s    =     15.8 : 1.0
#      contains(standards) = True              90s : 10s    =     15.8 : 1.0
#          contains(rates) = True              90s : 10s    =     15.8 : 1.0
#         contains(SCHOOL) = True              90s : 10s    =     15.7 : 1.0
#          contains(still) = True              90s : 10s    =     15.7 : 1.0
#          contains(rooms) = True              90s : 10s    =     15.6 : 1.0
#         contains(Female) = True              90s : 10s    =     15.6 : 1.0
#           contains(TYPE) = True              90s : 10s    =     15.6 : 1.0
#         contains(raised) = True              90s : 10s    =     15.6 : 1.0
#         contains(strong) = True              90s : 10s    =     15.6 : 1.0
#             contains(AT) = True              90s : 10s    =     15.5 : 1.0
#        contains(America) = True              90s : 10s    =     15.5 : 1.0
#       contains(software) = True              90s : 10s    =     15.4 : 1.0
#       contains(meanings) = True              10s : 90s    =     15.4 : 1.0
#            contains(age) = True              90s : 10s    =     15.4 : 1.0
#     contains(thereafter) = True              10s : 90s    =     15.3 : 1.0
#          contains(world) = True              90s : 10s    =     15.3 : 1.0
#          contains(trade) = True              90s : 10s    =     15.3 : 1.0
#     contains(individual) = True              90s : 10s    =     15.2 : 1.0
#           contains(turn) = True              90s : 10s    =     15.2 : 1.0
#       contains(Southern) = True              90s : 10s    =     15.2 : 1.0
#   contains(governmental) = True              10s : 90s    =     15.2 : 1.0
#       contains(arranged) = True              90s : 10s    =     15.1 : 1.0
#   contains(professional) = True              90s : 10s    =     15.1 : 1.0
#            contains(And) = True              90s : 10s    =     15.0 : 1.0
#             contains(DO) = True              90s : 10s    =     15.0 : 1.0
#           contains(took) = True              90s : 10s    =     14.9 : 1.0
#           contains(wide) = True              90s : 10s    =     14.9 : 1.0
#            contains(Apr) = True              90s : 10s    =     14.9 : 1.0
#            contains(III) = True              90s : 10s    =     14.9 : 1.0
#           contains(bury) = True              10s : 90s    =     14.8 : 1.0
#         contains(became) = True              90s : 10s    =     14.8 : 1.0
#             contains(CO) = True              90s : 10s    =     14.8 : 1.0
#          contains(class) = True              90s : 10s    =     14.7 : 1.0
#           contains(late) = True              90s : 10s    =     14.7 : 1.0
#      contains(incapable) = True              10s : 90s    =     14.7 : 1.0
#        contains(Johnson) = True              90s : 10s    =     14.6 : 1.0
#          contains(child) = True              90s : 10s    =     14.6 : 1.0
#        contains(Officer) = True              90s : 10s    =     14.5 : 1.0
#            contains(His) = True              90s : 10s    =     14.5 : 1.0
#         contains(INCOME) = True              90s : 10s    =     14.5 : 1.0
#        contains(century) = True              90s : 10s    =     14.5 : 1.0
#    contains(occupations) = True              90s : 10s    =     14.5 : 1.0
#     contains(procedures) = True              90s : 10s    =     14.4 : 1.0
#          contains(great) = True              90s : 10s    =     14.4 : 1.0
# contains(administrative) = True              90s : 10s    =     14.4 : 1.0
#       contains(Products) = True              90s : 10s    =     14.3 : 1.0
#        contains(medical) = True              90s : 10s    =     14.3 : 1.0
#         contains(Access) = True              90s : 10s    =     14.3 : 1.0
#            contains(Now) = True              90s : 10s    =     14.3 : 1.0
#          contains(Press) = True              90s : 10s    =     14.2 : 1.0
#         contains(Review) = True              90s : 10s    =     14.2 : 1.0
#           contains(book) = True              90s : 10s    =     14.2 : 1.0
#       contains(judicial) = True              10s : 90s    =     14.1 : 1.0
#     contains(Discipline) = True              90s : 10s    =     14.1 : 1.0
#   contains(METROPOLITAN) = True              90s : 10s    =     14.1 : 1.0
#          contains(MINOR) = True              90s : 10s    =     14.1 : 1.0
#            contains(TBS) = True              90s : 10s    =     14.1 : 1.0
#          contains(Lease) = True              10s : 90s    =     14.1 : 1.0
#          contains(began) = True              90s : 10s    =     14.1 : 1.0
#           contains(mind) = True              90s : 10s    =     14.1 : 1.0
#          contains(night) = True              90s : 10s    =     14.1 : 1.0
#      contains(HAZARDOUS) = True              10s : 90s    =     14.0 : 1.0
#         contains(Record) = True              90s : 10s    =     14.0 : 1.0
#   contains(Registration) = True              90s : 10s    =     14.0 : 1.0
#          contains(cubic) = True              10s : 90s    =     13.9 : 1.0
#          contains(games) = True              90s : 10s    =     13.9 : 1.0
#          contains(space) = True              90s : 10s    =     13.9 : 1.0
#          contains(thing) = True              90s : 10s    =     13.8 : 1.0
#       contains(Computer) = True              90s : 10s    =     13.8 : 1.0
#            contains(ond) = True              90s : 10s    =     13.8 : 1.0
#           contains(love) = True              90s : 10s    =     13.8 : 1.0
#           contains(went) = True              90s : 10s    =     13.8 : 1.0
#            contains(Red) = True              90s : 10s    =     13.6 : 1.0
#           contains(bore) = True              10s : 90s    =     13.6 : 1.0
#          contains(young) = True              90s : 10s    =     13.6 : 1.0
#         contains(lessee) = True              10s : 90s    =     13.5 : 1.0
#       contains(question) = True              90s : 10s    =     13.5 : 1.0
#         contains(tender) = True              10s : 90s    =     13.5 : 1.0
#      contains(education) = True              90s : 10s    =     13.5 : 1.0
#        contains(Atlanta) = True              90s : 10s    =     13.4 : 1.0
#        contains(minutes) = True              90s : 10s    =     13.3 : 1.0
#         contains(growth) = True              90s : 10s    =     13.3 : 1.0
#          contains(Chris) = True              90s : 10s    =     13.3 : 1.0
#       contains(incurred) = True              10s : 90s    =     13.2 : 1.0
#          contains(Staff) = True              90s : 10s    =     13.2 : 1.0
#            contains(got) = True              90s : 10s    =     13.2 : 1.0
#        contains(systems) = True              90s : 10s    =     13.1 : 1.0
#     contains(University) = True              90s : 10s    =     13.1 : 1.0
#       contains(programs) = True              90s : 10s    =     13.1 : 1.0
#         contains(virtue) = True              10s : 90s    =     13.0 : 1.0
#         contains(social) = True              90s : 10s    =     13.0 : 1.0
#          contains(light) = True              90s : 10s    =     13.0 : 1.0
#        contains(implied) = True              10s : 90s    =     13.0 : 1.0
#           contains(play) = True              90s : 10s    =     13.0 : 1.0
#         contains(Social) = True              90s : 10s    =     12.9 : 1.0
#           contains(eyes) = True              90s : 10s    =     12.9 : 1.0
#            contains(you) = True              90s : 10s    =     12.9 : 1.0
#          contains(drill) = True              10s : 90s    =     12.9 : 1.0
#           contains(John) = True              90s : 10s    =     12.9 : 1.0
#      contains(restoring) = True              10s : 90s    =     12.9 : 1.0
#       contains(physical) = True              90s : 10s    =     12.8 : 1.0
#       contains(interval) = True              10s : 90s    =     12.8 : 1.0
#        contains(Science) = True              90s : 10s    =     12.8 : 1.0
#          contains(Coach) = True              90s : 10s    =     12.7 : 1.0
#        contains(program) = True              90s : 10s    =     12.7 : 1.0
#     contains(horizontal) = True              10s : 90s    =     12.7 : 1.0
#    contains(publication) = True              90s : 10s    =     12.7 : 1.0
#        contains(arising) = True              10s : 90s    =     12.6 : 1.0
#         contains(series) = True              90s : 10s    =     12.6 : 1.0
#          contains(BLOCK) = True              90s : 10s    =     12.6 : 1.0
#           contains(That) = True              90s : 10s    =     12.6 : 1.0
#             contains(So) = True              90s : 10s    =     12.6 : 1.0
#           contains(hard) = True              90s : 10s    =     12.5 : 1.0
#       contains(agencies) = True              90s : 10s    =     12.5 : 1.0
#     contains(quantities) = True              10s : 90s    =     12.4 : 1.0
#  contains(international) = True              90s : 10s    =     12.4 : 1.0
#     contains(throughout) = True              90s : 10s    =     12.4 : 1.0
#            contains(SEC) = True              90s : 10s    =     12.4 : 1.0
#         contains(States) = True              90s : 10s    =     12.4 : 1.0
#         contains(Street) = True              90s : 10s    =     12.4 : 1.0
#          contains(table) = True              90s : 10s    =     12.4 : 1.0
#      contains(reservoir) = True              10s : 90s    =     12.4 : 1.0
#     contains(substances) = True              10s : 90s    =     12.4 : 1.0
#         contains(System) = True              90s : 10s    =     12.4 : 1.0
#         contains(worked) = True              90s : 10s    =     12.4 : 1.0
#    contains(termination) = True              10s : 90s    =     12.4 : 1.0
#        contains(consent) = True              10s : 90s    =     12.4 : 1.0
#         contains(Search) = True              90s : 10s    =     12.3 : 1.0
#            contains(him) = True              90s : 10s    =     12.3 : 1.0
#    contains(interrupted) = True              10s : 90s    =     12.3 : 1.0
#           contains(Farm) = True              90s : 10s    =     12.3 : 1.0
#             contains(He) = True              90s : 10s    =     12.3 : 1.0
#          contains(among) = True              90s : 10s    =     12.2 : 1.0
#           contains(role) = True              90s : 10s    =     12.2 : 1.0
#        contains(Special) = True              90s : 10s    =     12.2 : 1.0
#           contains(side) = True              90s : 10s    =     12.2 : 1.0
#          contains(asked) = True              90s : 10s    =     12.1 : 1.0
#        contains(effects) = True              90s : 10s    =     12.1 : 1.0
#          contains(plans) = True              90s : 10s    =     12.1 : 1.0
#            contains(Tax) = True              90s : 10s    =     12.1 : 1.0
#        contains(General) = True              90s : 10s    =     12.1 : 1.0
#            contains(key) = True              90s : 10s    =     12.0 : 1.0
# contains(Characteristics) = True              90s : 10s    =     12.0 : 1.0
#            contains(ing) = True              90s : 10s    =     12.0 : 1.0
#        contains(symbols) = True              90s : 10s    =     12.0 : 1.0
#       contains(pursuant) = True              10s : 90s    =     12.0 : 1.0
#        contains(foreign) = True              90s : 10s    =     11.9 : 1.0
#      contains(Community) = True              90s : 10s    =     11.8 : 1.0
#           contains(want) = True              90s : 10s    =     11.8 : 1.0
#         contains(agrees) = True              10s : 90s    =     11.8 : 1.0
#            contains(But) = True              90s : 10s    =     11.8 : 1.0
#        contains(example) = True              90s : 10s    =     11.8 : 1.0
#   contains(jurisdiction) = True              10s : 90s    =     11.8 : 1.0
#       contains(Premises) = True              10s : 90s    =     11.7 : 1.0
#          contains(bonus) = True              10s : 90s    =     11.7 : 1.0
#        contains(Finance) = True              90s : 10s    =     11.7 : 1.0
#          contains(going) = True              90s : 10s    =     11.7 : 1.0
#        contains(William) = True              90s : 10s    =     11.7 : 1.0
#         contains(letter) = True              90s : 10s    =     11.7 : 1.0
#       contains(carriers) = True              10s : 90s    =     11.6 : 1.0
#         contains(defend) = True              10s : 90s    =     11.6 : 1.0
#           contains(item) = True              90s : 10s    =     11.6 : 1.0
#         contains(things) = True              90s : 10s    =     11.6 : 1.0
#       contains(Employed) = True              90s : 10s    =     11.6 : 1.0
#          contains(North) = True              90s : 10s    =     11.6 : 1.0
#       contains(function) = True              90s : 10s    =     11.5 : 1.0
#   contains(nevertheless) = True              10s : 90s    =     11.5 : 1.0
#       contains(canceled) = True              10s : 90s    =     11.5 : 1.0
#      contains(estimates) = True              90s : 10s    =     11.5 : 1.0
#           contains(text) = True              90s : 10s    =     11.5 : 1.0
#            contains(yet) = True              90s : 10s    =     11.4 : 1.0
#       contains(Personal) = True              90s : 10s    =     11.4 : 1.0
#           contains(July) = True              90s : 10s    =     11.3 : 1.0
#         contains(fiscal) = True              90s : 10s    =     11.3 : 1.0
#         contains(tracts) = True              10s : 90s    =     11.3 : 1.0
#           contains(Past) = True              90s : 10s    =     11.3 : 1.0
#    contains(individuals) = True              90s : 10s    =     11.3 : 1.0
#      contains(mortgages) = True              10s : 90s    =     11.3 : 1.0
#      contains(selection) = True              90s : 10s    =     11.3 : 1.0
#           contains(From) = True              90s : 10s    =     11.3 : 1.0
#       contains(expected) = True              90s : 10s    =     11.3 : 1.0
#         contains(sector) = True              90s : 10s    =     11.3 : 1.0
#    contains(accordingly) = True              10s : 90s    =     11.2 : 1.0
#           contains(face) = True              90s : 10s    =     11.2 : 1.0
#        contains(poverty) = True              90s : 10s    =     11.2 : 1.0
#             contains(us) = True              90s : 10s    =     11.2 : 1.0
#              contains(F) = True              90s : 10s    =     11.2 : 1.0
#    contains(differences) = True              90s : 10s    =     11.2 : 1.0
#            contains(You) = True              90s : 10s    =     11.2 : 1.0
#            contains(Our) = True              90s : 10s    =     11.2 : 1.0
#     contains(concerning) = True              90s : 10s    =     11.2 : 1.0
#         contains(energy) = True              90s : 10s    =     11.2 : 1.0
#         contains(plants) = True              90s : 10s    =     11.2 : 1.0
#              contains(D) = True              90s : 10s    =     11.2 : 1.0
#           contains(They) = True              90s : 10s    =     11.2 : 1.0
#     contains(evaluation) = True              90s : 10s    =     11.1 : 1.0
#         contains(report) = True              90s : 10s    =     11.1 : 1.0
#     contains(Consistent) = True              90s : 10s    =     11.1 : 1.0
#         contains(origin) = True              90s : 10s    =     11.1 : 1.0
#             contains(HE) = True              90s : 10s    =     11.1 : 1.0
#           contains(Mean) = True              90s : 10s    =     11.1 : 1.0
#            contains(Jan) = True              90s : 10s    =     11.0 : 1.0
#          contains(Other) = True              90s : 10s    =     11.0 : 1.0
#    contains(obligations) = True              10s : 90s    =     11.0 : 1.0
#      contains(countries) = True              90s : 10s    =     11.0 : 1.0
#        contains(Workers) = True              90s : 10s    =     11.0 : 1.0
#          contains(James) = True              90s : 10s    =     11.0 : 1.0
#           contains(call) = True              90s : 10s    =     10.9 : 1.0
#     contains(prescribed) = True              10s : 90s    =     10.9 : 1.0
#     contains(prevailing) = True              10s : 90s    =     10.9 : 1.0
#         contains(course) = True              90s : 10s    =     10.9 : 1.0
#           contains(fall) = True              90s : 10s    =     10.9 : 1.0
#           contains(Then) = True              90s : 10s    =     10.9 : 1.0
#      contains(furnished) = True              10s : 90s    =     10.8 : 1.0
#            contains(sex) = True              90s : 10s    =     10.8 : 1.0
#         contains(little) = True              90s : 10s    =     10.8 : 1.0
#         contains(rather) = True              90s : 10s    =     10.7 : 1.0
#        contains(Studies) = True              90s : 10s    =     10.7 : 1.0
#           contains(UNIT) = True              90s : 10s    =     10.7 : 1.0
#            contains(gay) = True              90s : 10s    =     10.7 : 1.0
#           contains(East) = True              90s : 10s    =     10.7 : 1.0
#          contains(speed) = True              90s : 10s    =     10.7 : 1.0
#       contains(positive) = True              90s : 10s    =     10.7 : 1.0
#           contains(your) = True              90s : 10s    =     10.6 : 1.0
#         contains(notify) = True              10s : 90s    =     10.6 : 1.0
#          contains(phone) = True              90s : 10s    =     10.6 : 1.0
#        contains(thereof) = True              10s : 90s    =     10.6 : 1.0
#       contains(response) = True              90s : 10s    =     10.6 : 1.0
#             contains(er) = True              90s : 10s    =     10.6 : 1.0
#          contains(Level) = True              90s : 10s    =     10.6 : 1.0
#       contains(Business) = True              90s : 10s    =     10.6 : 1.0
#     contains(litigation) = True              10s : 90s    =     10.5 : 1.0
#         contains(remedy) = True              10s : 90s    =     10.5 : 1.0
#          contains(Trade) = True              90s : 10s    =     10.5 : 1.0
#            contains(her) = True              90s : 10s    =     10.5 : 1.0
#        contains(Control) = True              90s : 10s    =     10.5 : 1.0
#           contains(Less) = True              90s : 10s    =     10.5 : 1.0
#            contains(Mar) = True              90s : 10s    =     10.5 : 1.0
#       contains(category) = True              90s : 10s    =     10.5 : 1.0
#             contains(ae) = True              90s : 10s    =     10.5 : 1.0
#          contains(shows) = True              90s : 10s    =     10.5 : 1.0
#            contains(eee) = True              90s : 10s    =     10.4 : 1.0
#       contains(vicinity) = True              10s : 90s    =     10.4 : 1.0
#     contains(Department) = True              90s : 10s    =     10.4 : 1.0
#         contains(design) = True              90s : 10s    =     10.4 : 1.0
#             contains(AU) = True              90s : 10s    =     10.4 : 1.0
#           contains(June) = True              90s : 10s    =     10.3 : 1.0
#             contains(oe) = True              90s : 10s    =     10.3 : 1.0
#          contains(flood) = True              10s : 90s    =     10.3 : 1.0
#            contains(old) = True              90s : 10s    =     10.3 : 1.0
#          contains(bears) = True              10s : 90s    =     10.3 : 1.0
#            contains(Nov) = True              90s : 10s    =     10.3 : 1.0
#         contains(Health) = True              90s : 10s    =     10.3 : 1.0
#       contains(treating) = True              10s : 90s    =     10.3 : 1.0
#       contains(problems) = True              90s : 10s    =     10.3 : 1.0
#          contains(forms) = True              90s : 10s    =     10.2 : 1.0
#          contains(close) = True              90s : 10s    =     10.2 : 1.0
#        contains(numbers) = True              90s : 10s    =     10.2 : 1.0
#             contains(am) = True              90s : 10s    =     10.2 : 1.0
#       contains(research) = True              90s : 10s    =     10.2 : 1.0
#      contains(community) = True              90s : 10s    =     10.2 : 1.0
#          contains(think) = True              90s : 10s    =     10.2 : 1.0
#       contains(contrary) = True              10s : 90s    =     10.2 : 1.0
#      contains(functions) = True              90s : 10s    =     10.2 : 1.0
#  contains(approximately) = True              90s : 10s    =     10.2 : 1.0
#              contains(x) = True              90s : 10s    =     10.1 : 1.0
#         contains(Robert) = True              90s : 10s    =     10.1 : 1.0
#             contains(ST) = True              90s : 10s    =     10.1 : 1.0
#          contains(Total) = True              90s : 10s    =     10.1 : 1.0
#          contains(lease) = True              10s : 90s    =     10.1 : 1.0
#          contains(Notes) = True              90s : 10s    =     10.0 : 1.0
#           contains(game) = True              90s : 10s    =     10.0 : 1.0
#          contains(tools) = True              90s : 10s    =     10.0 : 1.0
#             contains(II) = True              90s : 10s    =     10.0 : 1.0
#             contains(IT) = True              90s : 10s    =     10.0 : 1.0
#        contains(applied) = True              90s : 10s    =      9.9 : 1.0
#     contains(assistance) = True              90s : 10s    =      9.9 : 1.0
#         contains(leased) = True              10s : 90s    =      9.9 : 1.0
#              contains(R) = True              90s : 10s    =      9.9 : 1.0
#            contains(job) = True              90s : 10s    =      9.9 : 1.0
#        contains(conform) = True              10s : 90s    =      9.9 : 1.0
#        contains(members) = True              90s : 10s    =      9.9 : 1.0
#          contains(about) = True              90s : 10s    =      9.9 : 1.0
#          contains(board) = True              90s : 10s    =      9.8 : 1.0
#       contains(children) = True              90s : 10s    =      9.8 : 1.0
#            contains(etc) = True              90s : 10s    =      9.8 : 1.0
#        contains(himself) = True              90s : 10s    =      9.8 : 1.0
#       contains(position) = True              90s : 10s    =      9.8 : 1.0
#     contains(statistics) = True              90s : 10s    =      9.8 : 1.0
#     contains(Birmingham) = True              90s : 10s    =      9.8 : 1.0
#        contains(Related) = True              90s : 10s    =      9.8 : 1.0
#         contains(always) = True              90s : 10s    =      9.8 : 1.0
#         contains(health) = True              90s : 10s    =      9.8 : 1.0
#         contains(likely) = True              90s : 10s    =      9.8 : 1.0
#          contains(Group) = True              90s : 10s    =      9.8 : 1.0
#       contains(drainage) = True              10s : 90s    =      9.7 : 1.0
#        contains(devised) = True              10s : 90s    =      9.7 : 1.0
#           contains(Some) = True              90s : 10s    =      9.7 : 1.0
#          contains(early) = True              90s : 10s    =      9.7 : 1.0
#       contains(reported) = True              90s : 10s    =      9.7 : 1.0
#    contains(application) = True              90s : 10s    =      9.7 : 1.0
#      contains(Committee) = True              90s : 10s    =      9.7 : 1.0
#        contains(earlier) = True              90s : 10s    =      9.7 : 1.0
#        contains(adverse) = True              10s : 90s    =      9.6 : 1.0
#         contains(groups) = True              90s : 10s    =      9.6 : 1.0
#           contains(life) = True              90s : 10s    =      9.6 : 1.0
#           contains(Lake) = True              90s : 10s    =      9.6 : 1.0
#            contains(New) = True              90s : 10s    =      9.6 : 1.0
#       contains(national) = True              90s : 10s    =      9.6 : 1.0
#         contains(Bureau) = True              90s : 10s    =      9.6 : 1.0
#       contains(analysis) = True              90s : 10s    =      9.6 : 1.0
#             contains(re) = True              90s : 10s    =      9.6 : 1.0
#             contains(AM) = True              90s : 10s    =      9.6 : 1.0
#        contains(mineral) = True              10s : 90s    =      9.6 : 1.0
#           contains(body) = True              90s : 10s    =      9.6 : 1.0
#   contains(notification) = True              10s : 90s    =      9.6 : 1.0
#     contains(constitute) = True              10s : 90s    =      9.5 : 1.0
#         contains(Region) = True              90s : 10s    =      9.5 : 1.0
#          contains(files) = True              90s : 10s    =      9.5 : 1.0
#       contains(decision) = True              90s : 10s    =      9.5 : 1.0
#          contains(These) = True              90s : 10s    =      9.5 : 1.0
#       contains(National) = True              90s : 10s    =      9.5 : 1.0
#          contains(LANDS) = True              10s : 90s    =      9.5 : 1.0
#        contains(Service) = True              90s : 10s    =      9.5 : 1.0
#           contains(Most) = True              90s : 10s    =      9.5 : 1.0
#      contains(prevented) = True              10s : 90s    =      9.5 : 1.0
#        contains(carries) = True              90s : 10s    =      9.4 : 1.0
#          contains(cases) = True              90s : 10s    =      9.4 : 1.0
#           contains(real) = True              90s : 10s    =      9.4 : 1.0
#       contains(Economic) = True              90s : 10s    =      9.4 : 1.0
#           contains(away) = True              90s : 10s    =      9.4 : 1.0
#         contains(review) = True              90s : 10s    =      9.4 : 1.0
#           contains(West) = True              90s : 10s    =      9.4 : 1.0
#            contains(our) = True              90s : 10s    =      9.4 : 1.0
#           contains(left) = True              90s : 10s    =      9.3 : 1.0
#           contains(four) = True              90s : 10s    =      9.3 : 1.0
#            contains(why) = True              90s : 10s    =      9.3 : 1.0
#             contains(na) = True              90s : 10s    =      9.3 : 1.0
#     contains(instrument) = True              10s : 90s    =      9.3 : 1.0
#           contains(What) = True              90s : 10s    =      9.3 : 1.0
#         contains(income) = True              90s : 10s    =      9.3 : 1.0
#         contains(School) = True              90s : 10s    =      9.3 : 1.0
#        contains(network) = True              90s : 10s    =      9.3 : 1.0
#          contains(alone) = True              90s : 10s    =      9.3 : 1.0
#  contains(International) = True              90s : 10s    =      9.3 : 1.0
#      contains(currently) = True              90s : 10s    =      9.3 : 1.0
#            contains(low) = True              90s : 10s    =      9.2 : 1.0
#            contains(lot) = True              90s : 10s    =      9.2 : 1.0
#            contains(Box) = True              90s : 10s    =      9.2 : 1.0
#           contains(plan) = True              90s : 10s    =      9.2 : 1.0
#        contains(Council) = True              90s : 10s    =      9.2 : 1.0
#       contains(vertical) = True              10s : 90s    =      9.2 : 1.0
#      contains(tolerance) = True              10s : 90s    =      9.2 : 1.0
#             contains(oo) = True              90s : 10s    =      9.2 : 1.0
#             contains(We) = True              90s : 10s    =      9.2 : 1.0
#           contains(lost) = True              90s : 10s    =      9.2 : 1.0
#         contains(animal) = True              90s : 10s    =      9.2 : 1.0
#        contains(delayed) = True              10s : 90s    =      9.1 : 1.0
#         contains(render) = True              10s : 90s    =      9.1 : 1.0
#          contains(large) = True              90s : 10s    =      9.1 : 1.0
#           contains(Uses) = True              90s : 10s    =      9.1 : 1.0
#        contains(privacy) = True              90s : 10s    =      9.1 : 1.0
#          contains(range) = True              90s : 10s    =      9.1 : 1.0
# ...
#    contains(occupations) = False             10s : 90s    =      1.1 : 1.0
#             contains(CN) = False             10s : 90s    =      1.1 : 1.0
#       contains(Hispanic) = False             10s : 90s    =      1.1 : 1.0
#     contains(discipline) = False             10s : 90s    =      1.1 : 1.0
#           contains(five) = False             90s : 10s    =      1.1 : 1.0
#            contains(ten) = False             90s : 10s    =      1.1 : 1.0
#        contains(poverty) = False             10s : 90s    =      1.1 : 1.0
#             contains(By) = False             10s : 90s    =      1.1 : 1.0
#      contains(statement) = False             10s : 90s    =      1.1 : 1.0
#        contains(revenue) = False             10s : 90s    =      1.1 : 1.0
#             contains(IN) = True              90s : 10s    =      1.1 : 1.0
#          contains(share) = False             10s : 90s    =      1.1 : 1.0
#      contains(operation) = False             90s : 10s    =      1.1 : 1.0
#     contains(indigenous) = False             10s : 90s    =      1.1 : 1.0
#        contains(council) = False             10s : 90s    =      1.1 : 1.0
#     contains(compliance) = True              90s : 10s    =      1.1 : 1.0
#          contains(ISSUE) = False             10s : 90s    =      1.1 : 1.0
#    contains(outstanding) = False             90s : 10s    =      1.1 : 1.0
#        contains(company) = False             10s : 90s    =      1.1 : 1.0
#       contains(Contents) = False             10s : 90s    =      1.1 : 1.0
#          contains(BLOCK) = False             10s : 90s    =      1.1 : 1.0
#          contains(filed) = False             90s : 10s    =      1.1 : 1.0
#          contains(ABOUT) = False             90s : 10s    =      1.1 : 1.0
#          contains(AREAS) = False             10s : 90s    =      1.1 : 1.0
#          contains(INPUT) = False             10s : 90s    =      1.1 : 1.0
#         contains(should) = True              90s : 10s    =      1.1 : 1.0
#            contains(act) = True              90s : 10s    =      1.1 : 1.0
#   contains(conservation) = False             90s : 10s    =      1.1 : 1.0
#          contains(makes) = False             90s : 10s    =      1.1 : 1.0
#          contains(Print) = False             10s : 90s    =      1.0 : 1.0
#          contains(Block) = False             10s : 90s    =      1.0 : 1.0
#  contains(Professionals) = False             10s : 90s    =      1.0 : 1.0
#        contains(illegal) = False             10s : 90s    =      1.0 : 1.0
#       contains(partners) = True              10s : 90s    =      1.0 : 1.0
#           contains(soil) = False             90s : 10s    =      1.0 : 1.0
#         contains(Energy) = False             10s : 90s    =      1.0 : 1.0
#            contains(sum) = False             90s : 10s    =      1.0 : 1.0
#       contains(selected) = False             90s : 10s    =      1.0 : 1.0
#    contains(Institution) = False             10s : 90s    =      1.0 : 1.0
#         contains(repair) = False             90s : 10s    =      1.0 : 1.0
#          contains(enter) = False             90s : 10s    =      1.0 : 1.0
#        contains(amounts) = True              10s : 90s    =      1.0 : 1.0
#           contains(Uses) = False             10s : 90s    =      1.0 : 1.0
#        contains(privacy) = False             10s : 90s    =      1.0 : 1.0
#             contains(AS) = False             90s : 10s    =      1.0 : 1.0
#        contains(OUTSIDE) = False             10s : 90s    =      1.0 : 1.0
#            contains(Sep) = False             10s : 90s    =      1.0 : 1.0
#         contains(covers) = False             90s : 10s    =      1.0 : 1.0
#       contains(facility) = False             10s : 90s    =      1.0 : 1.0
#      contains(allocated) = False             90s : 10s    =      1.0 : 1.0
#            contains(NOT) = False             90s : 10s    =      1.0 : 1.0
#            contains(ALL) = True              10s : 90s    =      1.0 : 1.0
#            contains(Aug) = False             10s : 90s    =      1.0 : 1.0
#     contains(Operations) = False             90s : 10s    =      1.0 : 1.0
#           contains(UNIT) = False             10s : 90s    =      1.0 : 1.0
#            contains(gay) = False             10s : 90s    =      1.0 : 1.0
#         contains(nature) = True              90s : 10s    =      1.0 : 1.0
#          contains(waste) = False             90s : 10s    =      1.0 : 1.0
#          contains(steps) = True              10s : 90s    =      1.0 : 1.0
#         contains(Topics) = False             10s : 90s    =      1.0 : 1.0
#     contains(identified) = False             10s : 90s    =      1.0 : 1.0
#         contains(simple) = False             10s : 90s    =      1.0 : 1.0
#    contains(opportunity) = False             10s : 90s    =      1.0 : 1.0
#            contains(Jun) = False             10s : 90s    =      1.0 : 1.0
#             contains(IN) = False             10s : 90s    =      1.0 : 1.0
#     contains(AUSTRALIAN) = False             10s : 90s    =      1.0 : 1.0
#     contains(Birmingham) = False             10s : 90s    =      1.0 : 1.0
#       contains(accounts) = True              10s : 90s    =      1.0 : 1.0
#             contains(BY) = True              90s : 10s    =      1.0 : 1.0
#       contains(contract) = False             10s : 90s    =      1.0 : 1.0
#            contains(EEE) = False             10s : 90s    =      1.0 : 1.0
#    contains(Explanatory) = False             10s : 90s    =      1.0 : 1.0
#       contains(building) = False             10s : 90s    =      1.0 : 1.0
#         contains(Median) = False             10s : 90s    =      1.0 : 1.0
#            contains(SEC) = False             10s : 90s    =      1.0 : 1.0
#         contains(Medium) = False             10s : 90s    =      1.0 : 1.0
#             contains(np) = False             10s : 90s    =      1.0 : 1.0
#     contains(technology) = False             90s : 10s    =      1.0 : 1.0
#         contains(values) = True              90s : 10s    =      1.0 : 1.0
#      contains(Copyright) = False             10s : 90s    =      1.0 : 1.0
#           contains(harm) = False             90s : 10s    =      1.0 : 1.0
#        contains(Purpose) = False             10s : 90s    =      1.0 : 1.0
#            contains(PAC) = False             10s : 90s    =      1.0 : 1.0
#         contains(Titles) = False             10s : 90s    =      1.0 : 1.0
#        contains(prevent) = False             10s : 90s    =      1.0 : 1.0
#     contains(Aboriginal) = False             10s : 90s    =      1.0 : 1.0
#       contains(Disposal) = False             10s : 90s    =      1.0 : 1.0
#            contains(Jul) = False             10s : 90s    =      1.0 : 1.0
#          contains(sound) = False             90s : 10s    =      1.0 : 1.0
#       contains(officers) = False             90s : 10s    =      1.0 : 1.0
#           contains(rule) = False             90s : 10s    =      1.0 : 1.0
#        contains(minimum) = False             10s : 90s    =      1.0 : 1.0
#     contains(Consistent) = False             10s : 90s    =      1.0 : 1.0
#         contains(actual) = True              10s : 90s    =      1.0 : 1.0
#    contains(enforcement) = False             90s : 10s    =      1.0 : 1.0
#       contains(Expanded) = False             10s : 90s    =      1.0 : 1.0
#  contains(qualification) = False             10s : 90s    =      1.0 : 1.0
#     contains(associated) = True              10s : 90s    =      1.0 : 1.0
#          contains(Force) = True              10s : 90s    =      1.0 : 1.0
#         contains(Auburn) = False             10s : 90s    =      1.0 : 1.0
#        contains(federal) = False             90s : 10s    =      1.0 : 1.0
#         contains(CENSUS) = False             10s : 90s    =      1.0 : 1.0
#        contains(dollars) = False             90s : 10s    =      1.0 : 1.0
#        contains(surveys) = False             90s : 10s    =      1.0 : 1.0
#       contains(proposed) = False             10s : 90s    =      1.0 : 1.0
#          contains(Units) = False             10s : 90s    =      1.0 : 1.0
#       contains(Grayling) = False             10s : 90s    =      1.0 : 1.0
#     contains(containing) = False             90s : 10s    =      1.0 : 1.0
#           contains(FROM) = False             90s : 10s    =      1.0 : 1.0
#            contains(NSW) = False             10s : 90s    =      1.0 : 1.0
#        contains(highest) = True              90s : 10s    =      1.0 : 1.0
#  contains(Participating) = False             10s : 90s    =      1.0 : 1.0
#       contains(transfer) = False             90s : 10s    =      1.0 : 1.0
#     contains(classified) = False             10s : 90s    =      1.0 : 1.0
#       contains(continue) = True              90s : 10s    =      1.0 : 1.0
#    contains(Description) = False             10s : 90s    =      1.0 : 1.0
#     contains(Discipline) = False             10s : 90s    =      1.0 : 1.0
#   contains(METROPOLITAN) = False             10s : 90s    =      1.0 : 1.0
#          contains(MINOR) = False             10s : 90s    =      1.0 : 1.0
#            contains(TBS) = False             10s : 90s    =      1.0 : 1.0
#       contains(Releases) = False             10s : 90s    =      1.0 : 1.0
#        contains(Natural) = False             10s : 90s    =      1.0 : 1.0
#     contains(disclosure) = False             10s : 90s    =      1.0 : 1.0
#           contains(WITH) = False             10s : 90s    =      1.0 : 1.0
#          contains(OTHER) = True              10s : 90s    =      1.0 : 1.0
#           contains(FSIS) = False             10s : 90s    =      1.0 : 1.0
#      contains(Numbering) = False             10s : 90s    =      1.0 : 1.0
#      contains(Retention) = False             10s : 90s    =      1.0 : 1.0
#         contains(nature) = False             10s : 90s    =      1.0 : 1.0
#  contains(Environmental) = False             10s : 90s    =      1.0 : 1.0
#        contains(Privacy) = False             10s : 90s    =      1.0 : 1.0
#    contains(maintenance) = False             10s : 90s    =      1.0 : 1.0
#            contains(act) = False             10s : 90s    =      1.0 : 1.0
#       contains(FOOTBALL) = False             10s : 90s    =      1.0 : 1.0
#       contains(relating) = False             90s : 10s    =      1.0 : 1.0
#            contains(MAY) = False             90s : 10s    =      1.0 : 1.0
#         contains(APPEAL) = False             10s : 90s    =      1.0 : 1.0
#            contains(BNA) = False             10s : 90s    =      1.0 : 1.0
#    contains(Householder) = False             10s : 90s    =      1.0 : 1.0
#    contains(householder) = False             10s : 90s    =      1.0 : 1.0
#           contains(mine) = False             90s : 10s    =      1.0 : 1.0
#      contains(Resources) = False             10s : 90s    =      1.0 : 1.0
#       contains(continue) = False             10s : 90s    =      1.0 : 1.0
#     contains(associated) = False             90s : 10s    =      1.0 : 1.0
#        contains(Website) = False             10s : 90s    =      1.0 : 1.0
#           contains(bank) = True              90s : 10s    =      1.0 : 1.0
#       contains(Released) = False             10s : 90s    =      1.0 : 1.0
#            contains(ALL) = False             90s : 10s    =      1.0 : 1.0
#          contains(steps) = False             90s : 10s    =      1.0 : 1.0
#         contains(number) = False             90s : 10s    =      1.0 : 1.0
#          contains(Skill) = False             10s : 90s    =      1.0 : 1.0
#        contains(Percent) = False             10s : 90s    =      1.0 : 1.0
#           contains(DECC) = False             90s : 10s    =      1.0 : 1.0
#           contains(LALC) = False             90s : 10s    =      1.0 : 1.0
#  contains(Accessibility) = False             10s : 90s    =      1.0 : 1.0
#    contains(Occupations) = False             10s : 90s    =      1.0 : 1.0
#        contains(tackles) = False             10s : 90s    =      1.0 : 1.0
#      contains(NUMBERING) = False             10s : 90s    =      1.0 : 1.0
#         contains(TRACTS) = False             10s : 90s    =      1.0 : 1.0
#          contains(yeors) = False             10s : 90s    =      1.0 : 1.0
#         contains(values) = False             10s : 90s    =      1.0 : 1.0
#            contains(HHH) = False             10s : 90s    =      1.0 : 1.0
#          contains(login) = False             10s : 90s    =      1.0 : 1.0
#        contains(amounts) = False             90s : 10s    =      1.0 : 1.0
#         contains(actual) = False             90s : 10s    =      1.0 : 1.0
#            contains(IPC) = False             10s : 90s    =      1.0 : 1.0
#        contains(Natasha) = False             10s : 90s    =      1.0 : 1.0
#             contains(BY) = False             10s : 90s    =      1.0 : 1.0
#        contains(highest) = False             10s : 90s    =      1.0 : 1.0
#          contains(Bucky) = False             10s : 90s    =      1.0 : 1.0
#        contains(Illegal) = False             90s : 10s    =      1.0 : 1.0
#          contains(Clint) = False             10s : 90s    =      1.0 : 1.0
#        contains(commons) = False             10s : 90s    =      1.0 : 1.0
#          contains(Force) = False             90s : 10s    =      1.0 : 1.0
#     contains(CONSIDERED) = False             10s : 90s    =      1.0 : 1.0
#         contains(dumped) = False             10s : 90s    =      1.0 : 1.0
#        contains(dumping) = False             10s : 90s    =      1.0 : 1.0
#      contains(illegally) = False             10s : 90s    =      1.0 : 1.0
#       contains(KEYWORDS) = False             10s : 90s    =      1.0 : 1.0
#         contains(claims) = True              90s : 10s    =      1.0 : 1.0
#         contains(number) = True              10s : 90s    =      1.0 : 1.0
#     contains(compliance) = False             10s : 90s    =      1.0 : 1.0
#         contains(AUBURN) = False             10s : 90s    =      1.0 : 1.0
#       contains(accounts) = False             90s : 10s    =      1.0 : 1.0
#      contains(structure) = True              10s : 90s    =      1.0 : 1.0
#       contains(partners) = False             90s : 10s    =      1.0 : 1.0
#        contains(defined) = True              90s : 10s    =      1.0 : 1.0
#          contains(Tract) = False             90s : 10s    =      1.0 : 1.0
#     contains(Disclaimer) = False             10s : 90s    =      1.0 : 1.0
#         contains(Angell) = False             10s : 90s    =      1.0 : 1.0
#            contains(PPU) = False             10s : 90s    =      1.0 : 1.0
#          contains(Zayas) = False             10s : 90s    =      1.0 : 1.0
#       contains(CANBERRA) = False             10s : 90s    =      1.0 : 1.0
#          contains(OTHER) = False             90s : 10s    =      1.0 : 1.0
#       contains(Archived) = False             10s : 90s    =      1.0 : 1.0
#        contains(neither) = True              10s : 90s    =      1.0 : 1.0
#          contains(Email) = False             10s : 90s    =      1.0 : 1.0
#         contains(ANZSCO) = False             90s : 10s    =      1.0 : 1.0
#         contains(HEHEHE) = False             90s : 10s    =      1.0 : 1.0
#           contains(bank) = False             10s : 90s    =      1.0 : 1.0
#        contains(created) = True              90s : 10s    =      1.0 : 1.0
#          contains(Darcy) = False             10s : 90s    =      1.0 : 1.0
#        contains(Primary) = True              10s : 90s    =      1.0 : 1.0
#      contains(structure) = False             90s : 10s    =      1.0 : 1.0
#         contains(claims) = False             10s : 90s    =      1.0 : 1.0
#        contains(defined) = False             10s : 90s    =      1.0 : 1.0
#      contains(regarding) = True              90s : 10s    =      1.0 : 1.0
#     contains(Indigenous) = False             10s : 90s    =      1.0 : 1.0
#       contains(ARCHIVED) = False             90s : 10s    =      1.0 : 1.0
#        contains(created) = False             10s : 90s    =      1.0 : 1.0
#        contains(neither) = False             90s : 10s    =      1.0 : 1.0
#      contains(regarding) = False             10s : 90s    =      1.0 : 1.0
#        contains(Primary) = False             90s : 10s    =      1.0 : 1.0

# %%
print("\n=== Concordance Analysis with POS Tagging ===")

# Create Text objects for each decade
text_1990s_tokens = [word for tokens, decade in texts if decade == "90s" for word in tokens]
text_2010s_tokens = [word for tokens, decade in texts if decade == "10s" for word in tokens]

# POS tagging
pos_1990s = nltk.pos_tag(text_1990s_tokens)
pos_2010s = nltk.pos_tag(text_2010s_tokens)

# Recreate Text objects with original tokens
text_1990s = Text(text_1990s_tokens)
text_2010s = Text(text_2010s_tokens)

# List of words for concordance analysis
word_list = ["hereof", "covenants", "undivided", "separator", "Notwithstanding", "Pooling", "therefrom", "Royalties", 
             "proportionately", "executors", "devisees", "thereunder", "Montana"]

def display_concordances_with_pos(word_list, text_1990s, text_2010s, pos_1990s, pos_2010s, width=80, lines=10):
    for word in word_list:
        print(f"\n=== Concordance and POS for '{word}' ===")
        
        # POS in 1990s text
        print("\n--- In 1990s Text ---")
        try:
            text_1990s.concordance(word, width=width, lines=lines)
            tags_1990s = [pos for token, pos in pos_1990s if token.lower() == word.lower()]
            print(f"POS Tags in 1990s: {tags_1990s}")
        except ValueError:
            print(f"'{word}' not found in 1990s text.")
        
        # POS in 2010s text
        print("\n--- In 2010s Text ---")
        try:
            text_2010s.concordance(word, width=width, lines=lines)
            tags_2010s = [pos for token, pos in pos_2010s if token.lower() == word.lower()]
            print(f"POS Tags in 2010s: {tags_2010s}")
        except ValueError:
            print(f"'{word}' not found in 2010s text.")

# Display concordances and POS tags for each word
display_concordances_with_pos(word_list, text_1990s, text_2010s, pos_1990s, pos_2010s)
# Out:
# === Concordance Analysis with POS Tagging ===
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 print("\n=== Concordance Analysis with POS Tagging ===")
#       3 # Create Text objects for each decade
# ----> 4 text_1990s_tokens = [word for tokens, decade in texts if decade == "90s" for word in tokens]
#       5 text_2010s_tokens = [word for tokens, decade in texts if decade == "10s" for word in tokens]
#       7 # POS tagging
#
# NameError: name 'texts' is not defined

# %%
file90 = cwd+"/beholdapalehorsebymiltonwilliamcooper1991_202003/Behold_a_Pale_Horse_by_Milton_William_Cooper_1991_djvu.txt"
file90_sub = open(file90, "r",encoding="utf8")
text90 = file90_sub.read()
file90_sub.close()
file10 = cwd+"/logo_modernism/Logo Modernism by Jens Müller_djvu.txt"
file10_sub = open(file10, "r",encoding="utf8")
text10 = file10_sub.read()
file10_sub.close()

# %%
text90 = nltk.word_tokenize(text90)
feature90 = text_features(text90)
text10 = nltk.word_tokenize(text10)
feature10 = text_features(text10)

# %%
classifier.classify_many([feature90,feature10])
# Out:
# ['90s', '90s']

# %% [markdown]
# ### Decision Tree

# %%
classifier2 = nltk.DecisionTreeClassifier.train(train_set)

# %%
print(nltk.classify.accuracy(classifier2, test_set)) # see the accuracy of the program
# Out:
# 0.8646616541353384

# %%
print(classifier2)
# Out:
# contains(Lessor)=False? ............................... 10s
#   contains(LALC)=False? ............................... 10s
#     contains(ARCHIVED)=False? ......................... 10s
#       contains(HEHEHE)=False? ......................... 10s
#       contains(HEHEHE)=True? .......................... 10s
#     contains(ARCHIVED)=True? .......................... 10s
#       contains(Indian)=False? ......................... 10s
#       contains(Indian)=True? .......................... 90s
#   contains(LALC)=True? ................................ 10s
# contains(Lessor)=True? ................................ 10s

# %%
classifier2.classify_many([feature90,feature10])
# Out:
# ['90s', '90s']
